# %% [markdown]
# # BrushCue Example: Parallelogram Area
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/parallelogram_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/parallelogram-area

# %%
# !pip install brushcue

# %%
import brushcue as bc

base = 4.0
height = 3.0
graph = bc.Float.multiply(base, height)

ctx = bc.Context()
print(graph.execute(ctx))
# Out:
# 12.0
# [wgpu] using backend Metal — adapter 'Apple M5' (IntegratedGpu), driver ''
