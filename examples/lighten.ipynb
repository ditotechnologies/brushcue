# %% [markdown]
# # BrushCue Example: Lighten
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/lighten.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/lighten

# %%
# !pip install brushcue

# %%
import io
from PIL import Image

import brushcue as bc

brightness = 0.15
graph = bc.Composition.monet_women_with_parasol().brightness_adjust(brightness)

ctx = bc.Context()
composition = graph.execute(ctx)
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400))  # Remove this line for full resolution
img
# Out:
# [wgpu] using backend Metal — adapter 'Apple M5' (IntegratedGpu), driver ''
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=322x400>
