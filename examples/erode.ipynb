# %% [markdown]
# # BrushCue Example: Erode
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/erode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/erode

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
erode_2 = brushcue.composition_morphological_min(input_image_1, 7)

ctx = brushcue.Context()
result = erode_2.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400)) # remove this line for full resolution
img
# Out:
# new pipeline: morphological_min_horizontal_rgba8unorm_compute_inarr_false
# new pipeline: morphological_min_vertical_rgba8unorm_compute_inarr_false
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=323x400>
