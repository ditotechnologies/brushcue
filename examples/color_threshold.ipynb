# %% [markdown]
# # BrushCue Example: Color Threshold
#
# <a href="https://colab.research.google.com/github/ditotechnologies/monorepo/blob/main/py/brushcue/examples/color_threshold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/color-threshold

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
float_constant_2 = brushcue.float_constant(0.14500001072883606)
threshold_3 = brushcue.float_passthrough(float_constant_2)
color_threshold_4 = brushcue.composition_color_threshold(input_image_1, threshold_3)
result_image_5 = brushcue.composition_passthrough(color_threshold_4)

ctx = brushcue.Context()
result = result_image_5.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1739x2160>
