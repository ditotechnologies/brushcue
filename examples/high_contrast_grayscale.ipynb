# %% [markdown]
# # BrushCue Example: High Contrast Grayscale
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/high_contrast_grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/high-contrast-grayscale

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
composition_grayscale_2 = brushcue.composition_grayscale(input_image_1)
float_add_3 = brushcue.float_add(1.0, 1.0)
curve_s_4 = brushcue.curve_s_curve(0.5, float_add_3, 1.0, 1.0)
composition_lightness_curve_5 = brushcue.composition_l_curve(composition_grayscale_2, curve_s_4)

ctx = brushcue.Context()
result = composition_lightness_curve_5.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400)) # remove this line for full resolution
img
# Out:
# new pipeline: color_transformer_shader_rgba16float_compute_7632792453062843270_inarr_false
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=322x400>
