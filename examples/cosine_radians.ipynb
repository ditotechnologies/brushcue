# %% [markdown]
# # BrushCue Example: Cosine (Radians)
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/cosine_radians.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/cosine-radians

# %%
# !pip install brushcue

# %%
import brushcue as bc

angle_radians = 1.0471976
graph = bc.Float.cos(angle_radians)

ctx = bc.Context()
print(graph.execute(ctx))
# Out:
# 0.4999999701976776
# [wgpu] using backend Metal — adapter 'Apple M5' (IntegratedGpu), driver ''
