# %% [markdown]
# # BrushCue Example: Convert to Display P3
#
# <a href="https://colab.research.google.com/github/ditotechnologies/monorepo/blob/main/py/brushcue/examples/convert_to_display_p3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/convert-to-display-p3

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
color_profile_p3_2 = brushcue.color_profile_p3()
color_convert_3 = brushcue.composition_color_convert(input_image_1, color_profile_p3_2)

ctx = brushcue.Context()
result = color_convert_3.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400)) # remove this line for full resolution
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=322x400>
