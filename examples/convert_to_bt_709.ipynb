# %% [markdown]
# # BrushCue Example: Convert to BT.709
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/convert_to_bt_709.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/convert-to-bt-709

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
color_profile_bt_709_2 = brushcue.color_profile_b_t709()
composition_color_convert_3 = brushcue.composition_color_convert(input_image_1, color_profile_bt_709_2)

ctx = brushcue.Context()
result = composition_color_convert_3.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400)) # remove this line for full resolution
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=322x400>
