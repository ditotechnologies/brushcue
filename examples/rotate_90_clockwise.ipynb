# %% [markdown]
# # BrushCue Example: Rotate 90° Clockwise
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/rotate_90_clockwise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/rotate-90-clockwise

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
composition_rotate_90_clockwise_2 = brushcue.composition_rotate90_clockwise(input_image_1)

ctx = brushcue.Context()
result = composition_rotate_90_clockwise_2.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400)) # remove this line for full resolution
img
# Out:
# new pipeline: modify_orientation_compute_rgba8unorm_rotate_90_clockwise_inarr_false
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x322>
