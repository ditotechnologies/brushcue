# %% [markdown]
# # BrushCue Example: Color Invert
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/color_invert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/color-invert

# %%
# !pip install brushcue

# %%
import io
from PIL import Image

import brushcue as bc

graph = bc.Composition.monet_women_with_parasol().color_invert()

ctx = bc.Context()
composition = graph.execute(ctx)
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400))  # Remove this line for full resolution
img
# Out:
# new pipeline: color_transformer_shader_rgba16float_compute_3951939299502643100_inarr_false
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=322x400>
