# %% [markdown]
# # BrushCue Example: Degrees to Radians
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/degrees_to_radians.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/degrees-to-radians

# %%
# !pip install brushcue

# %%
import brushcue as bc

degrees = 180.0
graph = bc.Float.divide(bc.Float.multiply(degrees, bc.Float.pi()), 180.0)

ctx = bc.Context()
print(graph.execute(ctx))
# Out:
# 3.1415927410125732
# [wgpu] using backend Metal — adapter 'Apple M5' (IntegratedGpu), driver ''
