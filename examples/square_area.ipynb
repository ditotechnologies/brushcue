# %% [markdown]
# # BrushCue Example: Square Area
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/square_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/square-area

# %%
# !pip install brushcue

# %%
import brushcue as bc

side = 4.0
graph = bc.Float.squared(side)

ctx = bc.Context()
print(graph.execute(ctx))
# Out:
# 16.0
# [wgpu] using backend Metal — adapter 'Apple M5' (IntegratedGpu), driver ''
