# %% [markdown]
# # BrushCue Example: Vertical Mirror
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/vertical_mirror.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/vertical-mirror

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
composition_flip_vertical_2 = brushcue.composition_flip_vertical(input_image_1)

ctx = brushcue.Context()
result = composition_flip_vertical_2.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400)) # remove this line for full resolution
img
# Out:
# new pipeline: modify_orientation_compute_rgba8unorm_flip_vertical_inarr_false
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=322x400>
