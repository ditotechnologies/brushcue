# %% [markdown]
# # BrushCue Example: Negative Filter
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/negative_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/negative-filter

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
composition_negative_2 = brushcue.composition_negative(input_image_1)

ctx = brushcue.Context()
result = composition_negative_2.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400)) # remove this line for full resolution
img
# Out:
# new pipeline: color_transformer_shader_rgba16float_compute_11876854719037224982_inarr_false
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=322x400>
