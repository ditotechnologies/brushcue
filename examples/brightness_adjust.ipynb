# %% [markdown]
# # BrushCue Example: Brightness Adjust
#
# <a href="https://colab.research.google.com/github/ditotechnologies/brushcue/blob/main/examples/brightness_adjust.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/brightness-adjust

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
composition_brightness_adjust_2 = brushcue.composition_brightness_adjust(input_image_1, -0.000000011175871)

ctx = brushcue.Context()
result = composition_brightness_adjust_2.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img.thumbnail((400, 400)) # remove this line for full resolution
img
# Out:
# creating texture TextureKey { size: (1739, 2160, 1), format: Rgba8Unorm, usage_style: Storage }
# creating texture TextureKey { size: (1792, 2304, 1), format: Rgba16Float, usage_style: Storage }
# creating texture TextureKey { size: (1792, 2304, 1), format: Rgba16Float, usage_style: Storage }
# creating texture TextureKey { size: (1792, 2304, 1), format: Rgba16Float, usage_style: Storage }
# creating texture TextureKey { size: (1792, 2304, 1), format: Rgba16Float, usage_style: Storage }
# creating texture TextureKey { size: (1792, 2304, 1), format: Rgba16Float, usage_style: Storage }
# creating texture TextureKey { size: (1739, 2160, 1), format: Rgba16Float, usage_style: Storage }
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=322x400>
