# %% [markdown]
# # BrushCue Example: Box Blur
#
# <a href="https://colab.research.google.com/github/ditotechnologies/monorepo/blob/main/py/brushcue/examples/box_blur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# You can use this tool online at https://www.brushcue.com/tools/box-blur

# %%
# !pip install brushcue

# %%
import brushcue
from PIL import Image
import io

input_image_1 = brushcue.composition_monet_women_with_parasol() # insert your own image here
int_constant_2 = brushcue.int_constant(8)
dimension_3 = brushcue.int_passthrough(int_constant_2)
composition_box_blur_4 = brushcue.composition_box_blur(input_image_1, dimension_3)
box_blur_result_5 = brushcue.composition_passthrough(composition_box_blur_4)

ctx = brushcue.Context()
result = box_blur_result_5.execute(ctx)
composition = result.as_composition()
data_bytes = composition.to_image_bytes(ctx)
img = Image.open(io.BytesIO(data_bytes))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1739x2160>
